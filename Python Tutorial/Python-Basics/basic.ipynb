# %%
##this is single line comment
print("Hello, World!")  # This prints a greeting message
# Out:
# Hello, World!

# %%
'''this is multi line comment'''
print("Welcome to Python programming!")
# Out:
# Welcome to Python programming!

# %%
name="Raja"
Name="Naidu"

print(name)
print(Name)
# Out:
# Raja
# Naidu

# %%
##indentation
##python uses indentation to define blocks of code
age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
###this is single line comment
print("Hello, World!")  # This prints a greeting message
# Out:
# Hello, World!

# %%
##line continuation
total = 1+2+3+\
        4+5+6
print(total)
# Out:
# 21

# %%
##multiple statements in a single line
x = 5; y = 10; z=x+y
print(z)
# Out:
# 15

# %%
##undestand symantics in python
age=32 ##age
name="Raja"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
variable= 10
print(type(variable))
variable= "Hello"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
   print(age)
# Out:
# 32

# %%
##name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
##code examples of identation errors
if True:
    print("correct indentation")
    if False:
        print("This wont print")
    print("this will print")  
print("outside if block")
# Out:
# correct indentation
# this will print
# outside if block

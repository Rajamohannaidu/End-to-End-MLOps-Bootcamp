# %%
##Integers example
age=35
type(age)
# Out:
# int

# %%
##floating point data type
height=5.9
print(height)
print(type(height))
# Out:
# 5.9
# <class 'float'>

# %%
##string data type example
name="Raja"
print(name)
print(type(name))
# Out:
# Raja
# <class 'str'>

# %%
##boolean data type example
is_true=bool()
type(is_true)
# Out:
# bool

# %%
a=10
b=10

a==b
# Out:
# True

# %%
##common errors
result="Hello" + str(5)
print(result)
# Out:
# Hello5
